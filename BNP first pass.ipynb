# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import mca

# %%
trset = pd.read_csv("train.csv")
trset
# Out:
#             ID  target            v1         v2   v3        v4         v5  \
# 0            3       1  1.335739e+00   8.727474    C  3.921026   7.915266
# 1            4       1           NaN        NaN    C       NaN   9.191265
# 2            5       1  9.438769e-01   5.310079    C  4.410969   5.326159
# 3            6       1  7.974146e-01   8.304757    C  4.225930  11.627438
# 4            8       1           NaN        NaN    C       NaN        NaN
# 5            9       0           NaN        NaN    C       NaN   8.856791
# 6           12       0  8.998057e-01   7.312995    C  3.494148   9.946200
# 7           21       1           NaN        NaN    C       NaN        NaN
# 8           22       0  2.078651e+00   8.462619  NaN  3.739030   5.265636
# 9           23       1  1.144802e+00   5.880606    C  3.244469   9.538384
# 10          24       1           NaN        NaN    C       NaN        NaN
# 11          27       1           NaN        NaN    C       NaN        NaN
# ...

# %%
trset.head()
# Out:
#    ID  target        v1        v2 v3        v4         v5        v6        v7  \
# 0   3       1  1.335739  8.727474  C  3.921026   7.915266  2.599278  3.176895
# 1   4       1       NaN       NaN  C       NaN   9.191265       NaN       NaN
# 2   5       1  0.943877  5.310079  C  4.410969   5.326159  3.979592  3.928571
# 3   6       1  0.797415  8.304757  C  4.225930  11.627438  2.097700  1.987549
# 4   8       1       NaN       NaN  C       NaN        NaN       NaN       NaN
#
#          v8    ...         v122      v123      v124  v125      v126      v127  \
# 0  0.012941    ...     8.000000  1.989780  0.035754    AU  1.804126  3.113719
# 1  2.301630    ...          NaN       NaN  0.598896    AF       NaN       NaN
# 2  0.019645    ...     9.333333  2.477596  0.013452    AE  1.773709  3.922193
# 3  0.171947    ...     7.018256  1.812795  0.002267    CJ  1.415230  2.954381
# 4       NaN    ...          NaN       NaN       NaN     Z       NaN       NaN
#
# ...

# %%
trset_des = trset.describe()

# %%
trset_des
# Out:
#                   ID         target            v1            v2            v4  \
# count  114321.000000  114321.000000  6.448900e+04  6.452500e+04  6.452500e+04
# mean   114228.928228       0.761199  1.630686e+00  7.464411e+00  4.145098e+00
# std     65934.487362       0.426353  1.082813e+00  2.961676e+00  1.148263e+00
# min         3.000000       0.000000 -9.996497e-07 -9.817614e-07 -6.475929e-07
# 25%     57280.000000       1.000000  9.135798e-01  5.316428e+00  3.487398e+00
# 50%    114189.000000       1.000000  1.469550e+00  7.023803e+00  4.205991e+00
# 75%    171206.000000       1.000000  2.136128e+00  9.465497e+00  4.833250e+00
# max    228713.000000       1.000000  2.000000e+01  2.000000e+01  2.000000e+01
#
#                  v5            v6            v7            v8            v9  \
# count  6.569700e+04  6.448900e+04  6.448900e+04  6.570200e+04  6.447000e+04
# mean   8.742359e+00  2.436402e+00  2.483921e+00  1.496569e+00  9.031859e+00
# ...

# %%
trset_desT = trset_des.T

# %%
trset_desT
# Out:
#          count           mean           std           min           25%  \
# ID      114321  114228.928228  65934.487362  3.000000e+00  5.728000e+04
# target  114321       0.761199      0.426353  0.000000e+00  1.000000e+00
# v1       64489       1.630686      1.082813 -9.996497e-07  9.135798e-01
# v2       64525       7.464411      2.961676 -9.817614e-07  5.316428e+00
# v4       64525       4.145098      1.148263 -6.475929e-07  3.487398e+00
# v5       65697       8.742359      2.036018 -5.287068e-07  7.605918e+00
# v6       64489       2.436402      0.599965 -9.055091e-07  2.065064e+00
# v7       64489       2.483921      0.589449 -9.468765e-07  2.101477e+00
# v8       65702       1.496569      2.783003 -7.783778e-07  8.658986e-02
# v9       64470       9.031859      1.930262 -9.828757e-07  7.853659e+00
# v10     114237       1.883046      1.393979 -9.875317e-07  1.050328e+00
# v11      64485      15.447413      0.790079 -1.459062e-07  1.500000e+01
# ...

# %%
trset_desT.sort_values('max', ascending = False)
# Out:
#          count           mean           std           min           25%  \
# ID      114321  114228.928228  65934.487362  3.000000e+00  5.728000e+04
# v109     65697       4.181284      3.712001 -9.996884e-07  1.842106e+00
# v25      65702       1.698129      2.956854  4.104324e-02  1.496663e-01
# v124     65702       0.919812      2.099407 -9.994953e-07  2.053777e-02
# v69      64426       9.449335      1.900495 -9.920262e-07  8.389830e+00
# v100     64485      12.091623      6.888297 -9.981311e-07  5.754166e+00
# v23      63646       1.093088      4.003695 -9.999932e-07 -4.093461e-07
# v63      65702       1.687327      2.967313  5.305528e-02  1.424455e-01
# v89      65702       1.518425      2.812902  2.236518e-02  9.964509e-02
# v8       65702       1.496569      2.783003 -7.783778e-07  8.658986e-02
# v54      65702       1.253856      2.314476  1.306150e-02  9.309360e-02
# v46      65702       1.630525      2.895831  6.934879e-02  1.237072e-01
# ...

# %%
trset_desT_highCount = trset_desT.sort_values('count', ascending = False)
trset_desT_highCount
# Out:
#          count           mean           std           min           25%  \
# ID      114321  114228.928228  65934.487362  3.000000e+00  5.728000e+04
# v38     114321       0.090928      0.583478  0.000000e+00  0.000000e+00
# v72     114321       1.431767      0.922267  0.000000e+00  1.000000e+00
# target  114321       0.761199      0.426353  0.000000e+00  1.000000e+00
# v62     114321       1.030694      0.696244  0.000000e+00  1.000000e+00
# v129    114321       0.310144      0.693262  0.000000e+00  0.000000e+00
# v14     114317      12.094279      1.443947 -9.738831e-07  1.125602e+01
# v114    114291      13.574451      2.613221 -9.335327e-10  1.199531e+01
# v10     114237       1.883046      1.393979 -9.875317e-07  1.050328e+00
# v12     114235       6.881304      0.924495  5.143224e-07  6.322471e+00
# v50     114235       1.504265      1.168329 -9.091393e-07  6.587918e-01
# v40     114210      10.465928      3.169183  1.238996e-07  8.408220e+00
# ...

# %%
trset_desT_highCount = trset_desT_highCount.rename(columns = {'count':'counts'})
trset_HF = trset_desT_highCount[trset_desT_highCount.counts>113000]
trset_HFL = list(trset_HF.index.values)
trset_HFL
# Out:
# ['ID',
#  'v38',
#  'v72',
#  'target',
#  'v62',
#  'v129',
#  'v14',
#  'v114',
#  'v10',
#  'v12',
#  'v50',
#  'v40',
#  'v34',
#  'v21']

# %%
trset_HFdata = trset[trset_HFL]
trset_HFdata
# Out:
#             ID  v38  v72  target  v62  v129        v14       v114       v10  \
# 0            3    0    1       1    1     0  11.636387  15.634907  0.503281
# 1            4    0    2       1    2     0  11.636386  10.308044  1.312910
# 2            5    0    3       1    1     2   9.603542  11.205561  0.765864
# 3            6    0    2       1    1     1  14.094723  13.777666  6.542669
# 4            8    0    1       1    1     0  10.991098  14.097099  1.050328
# 5            9    0    1       0    1     0  11.916255  15.750502  1.050328
# 6           12    0    2       0    2     0  12.148604   9.010082  2.341356
# 7           21    0    2       1    2     0  12.793945  18.705610  1.838074
# 8           22    0    0       0    0     0  12.603403  12.536835  4.463894
# 9           23    0    3       1    3     0  13.790046  13.434123  2.363238
# 10          24    0    1       1    1     0  12.670870   9.140132  1.312910
# ...

# %%
trset_HFdata.describe()
# Out:
#                   ID            v38            v72         target  \
# count  114321.000000  114321.000000  114321.000000  114321.000000
# mean   114228.928228       0.090928       1.431767       0.761199
# std     65934.487362       0.583478       0.922267       0.426353
# min         3.000000       0.000000       0.000000       0.000000
# 25%     57280.000000       0.000000       1.000000       1.000000
# 50%    114189.000000       0.000000       1.000000       1.000000
# 75%    171206.000000       0.000000       2.000000       1.000000
# max    228713.000000      12.000000      12.000000       1.000000
#
#                  v62           v129           v14          v114           v10  \
# count  114321.000000  114321.000000  1.143170e+05  1.142910e+05  1.142370e+05
# mean        1.030694       0.310144  1.209428e+01  1.357445e+01  1.883046e+00
# std         0.696244       0.693262  1.443947e+00  2.613221e+00  1.393979e+00
# ...

# %%
trset0 = trset[trset.target<1]

# %%
trset0_des=trset0.describe()
trset0_desT = trset0_des.T
trset0_desT
# Out:
#         count           mean           std           min           25%  \
# ID      27300  114238.340330  66216.399794  9.000000e+00  5.682175e+04
# target  27300       0.000000      0.000000  0.000000e+00  0.000000e+00
# v1      15844       1.646081      1.094666 -9.989552e-07  9.169767e-01
# v2      15854       7.274653      2.960547 -8.757841e-07  5.095765e+00
# v4      15854       4.024702      1.154877  7.364053e-07  3.344086e+00
# v5      16193       8.662844      2.012887  1.815737e-01  7.545394e+00
# v6      15844       2.404222      0.603015 -6.111700e-07  2.034968e+00
# v7      15844       2.449455      0.580614 -9.291187e-07  2.066313e+00
# v8      16193       1.552248      2.814769  3.087089e-04  9.752800e-02
# v9      15840       9.074359      1.910307 -5.680370e-07  7.894737e+00
# v10     27299       1.513185      1.093370 -9.547834e-07  1.050327e+00
# v11     15843      15.431097      0.782930  7.900000e+00  1.498220e+01
# ...

# %%
trset1 = trset[trset.target>0]
trset1_des=trset1.describe()
trset1_desT = trset1_des.T
trset1_desT
# Out:
#         count           mean           std           min           25%  \
# ID      87021  114225.975489  65846.179123  3.000000e+00  5.746300e+04
# target  87021       1.000000      0.000000  1.000000e+00  1.000000e+00
# v1      48645       1.625671      1.078889 -9.996497e-07  9.127361e-01
# v2      48671       7.526222      2.959448 -9.817614e-07  5.379228e+00
# v4      48671       4.184315      1.143377 -6.475929e-07  3.535430e+00
# v5      49504       8.768369      2.042876 -5.287068e-07  7.634282e+00
# v6      48645       2.446883      0.598601 -9.055091e-07  2.073669e+00
# v7      48645       2.495146      0.591870 -9.468765e-07  2.111959e+00
# v8      49509       1.478357      2.772320 -7.783778e-07  8.343070e-02
# v9      48630       9.018015      1.936536 -9.828757e-07  7.836799e+00
# v10     86938       1.999184      1.456550 -9.875317e-07  1.050329e+00
# v11     48642      15.452727      0.792329 -1.459062e-07  1.500914e+01
# ...

# %%
catlabels = ['target'];
trset_alllabels = list(trset.columns.values)
trset_numlabels = list(trset1_desT.index.values)
for label in trset_alllabels:
    if label not in trset_numlabels:
        print(label)
        catlabels.append(label)
# Out:
# v3
# v22
# v24
# v30
# v31
# v47
# v52
# v56
# v66
# v71
# v74
# v75
# v79
# v91
# v107
# v110
# v112
# v113
# v125

# %%
catlabels
# Out:
# ['target',
#  'v3',
#  'v22',
#  'v24',
#  'v30',
#  'v31',
#  'v47',
#  'v52',
#  'v56',
#  'v66',
#  'v71',
#  'v74',
#  'v75',
#  'v79',
#  'v91',
#  'v107',
#  'v110',
#  'v112',
#  'v113',
#  'v125']

# %%
trset.dtypes
catdf = trset.select_dtypes(include=['object'])
catdf.insert(0,'ID',trset.ID)
catdf.insert(1,'target',trset.target)
catdf = catdf.set_index('ID')
catdf = catdf.fillna('None')
catdf.head(150)
# Out:
#      target    v3   v22 v24   v30   v31 v47 v52   v56 v66 v71 v74 v75 v79 v91  \
# ID
# 3         1     C   XDX   C     C     A   C   G    DI   C   F   B   D   E   A
# 4         1     C   GUV   C     C     A   E   G    DY   A   F   B   D   D   B
# 5         1     C    FQ   E  None     A   C   F    AS   A   B   B   B   E   G
# 6         1     C  ACUE   D     C     B   C   H    BW   A   F   B   D   B   B
# 8         1     C   HIT   E  None     A   I   H  None   C   F   B   D   C   G
# 9         0     C   AYX   A  None     A   I   K    DX   A   F   B   D   I   G
# 12        0     C   NFD   E     G     A   C   A    AS   A   F   B   D   E   B
# 21        1     C  AHBW   D     C     A   I   C    DP   C   F   B   D   C   A
# 22        0  None   GKQ   E  None  None   D   H    AF   B   B   B   B   P   C
# 23        1     C   PYF   C     C     A   I   A  None   A   F   B   D   C   A
# 24        1     C   GEH   E     D     A   I   E    CY   A   F   B   D   C   F
# ...

# %%
catdf.v3.unique()
# Out:
# array(['C', nan, 'A', 'B'], dtype=object)

# %%
np.unique(catdf.v22,return_counts=True)
# Out:
# (array(['AA', 'AAA', 'AAAA', ..., 'ZZV', 'ZZW', 'ZZZ'], dtype=object),
#  array([ 5,  3,  1, ...,  1, 48,  5], dtype=int64))

# %%
catdf.v71.unique()
# Out:
# array(['F', 'B', 'C', 'L', 'I', 'A', 'G', 'K', 'D'], dtype=object)

# %%
catdf.v75.unique()
# Out:
# array(['D', 'B', 'C', 'A'], dtype=object)
